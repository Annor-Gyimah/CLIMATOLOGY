# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 82F4-2075
#
#  Directory of C:\Users\Annorion\Desktop\PROJECTS\CLIMATOLOGY\alifo
#
# 04/29/2023  04:42 PM    <DIR>          .
# 04/29/2023  04:42 PM    <DIR>          ..
# 04/29/2023  04:42 PM    <DIR>          .ipynb_checkpoints
# 04/25/2023  05:37 AM         4,738,877 PERSIANN_Pakistan_2023-04-25053554am_2010.nc
# 04/25/2023  05:37 AM         4,743,118 PERSIANN_Pakistan_2023-04-25053554am_2011.nc
# 04/25/2023  05:37 AM         4,739,363 PERSIANN_Pakistan_2023-04-25053554am_2012.nc
# 04/25/2023  05:37 AM         4,764,627 PERSIANN_Pakistan_2023-04-25053554am_2013.nc
# 04/25/2023  05:37 AM         4,770,198 PERSIANN_Pakistan_2023-04-25053554am_2014.nc
# 04/25/2023  05:37 AM         4,804,899 PERSIANN_Pakistan_2023-04-25053554am_2015.nc
# 04/25/2023  05:37 AM         4,737,987 PERSIANN_Pakistan_2023-04-25053554am_2016.nc
# 04/25/2023  05:37 AM         4,773,058 PERSIANN_Pakistan_2023-04-25053554am_2017.nc
# ...

# %%
import xarray as xr
ds = xr.open_mfdataset("*.nc")
ds
# Out:
# <xarray.Dataset>
# Dimensions:   (lon: 67, lat: 56, datetime: 3652)
# Coordinates:
#   * lon       (lon) float32 60.75 61.0 61.25 61.5 ... 76.5 76.75 77.0 77.25
#   * lat       (lat) float32 37.5 37.25 37.0 36.75 36.5 ... 24.5 24.25 24.0 23.75
#   * datetime  (datetime) datetime64[ns] 2010-01-01 2010-01-02 ... 2019-12-31
# Data variables:
#     crs       (datetime) int32 -2147483647 -2147483647 ... -2147483647
#     precip    (datetime, lat, lon) float32 dask.array<chunksize=(365, 56, 67), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
